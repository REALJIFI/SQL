# %% [markdown]
# <a href="https://colab.research.google.com/github/REALJIFI/SQL/blob/main/Copy_of_Python_Basics_Assignment_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Number -  Integer and Float

# %%
# What is the data type for 100
# What is the data type for 100.05
# Use print
A = 100
B = 100.05

print(type(A))
print(type(B))
#--------------- Write your code below----------------------------#
# Out:
# <class 'int'>
# <class 'float'>

# %%
# Basic Arithmetic
# what is 15% of 200
0.15 * 200
#--------------- Write your code below----------------------------#
# Out:
# 30.0

# %%
# Juanita’s salary is $2,650.00 per month. If she receives a salary increase of 5%, what is her new monthly salary?
Salary = 2650
increase = 5
new_salary = (Salary * increase) / 100 #--------------- Write your code below----------------------------#
print(new_salary)
# Out:
# 132.5

# %%
# Jasper collects 1,082 cans of food. He gives a certain number of cans to the first local charity he finds.
# He now has 602 cans of food. How many cans of food did he give to the first local charity?
1082 - 602
#--------------- Write your code below----------------------------#
# Out:
# 480

# %%
# what is the square root of 100
import math
sqrt_100 = math.sqrt(100)
print(sqrt_100)
#--------------- Write your code below----------------------------#
# Out:
# 10.0

# %% [markdown]
# ## Variable Assignment - Integers and Floats

# %%
# what is the difference between income and tax i.e. income - tax and assign it to disposbale income
# disposable_income = income - tax
# Use input
income = 500
tax = 300
disposable_income = input("income - tax: ")
print()


#--------------- Write your code below----------------------------#
# Out:
# income - tax: 200

# %%
# Pamela’s salary is $3125.00 per month. If she receives a salary increase of 5%, her new monthly salary is:
pam_sal = 3125
sal_increase = 0.05
(pam_sal * sal_increase) / 100
input("new monthly salary: ")
print()
#--------------- Write your code below----------------------------#
# Out:
# new monthly salary: 157.6

# %%
# You plan to forecast using the Simple Liner Forecast (Y = a + bx). What is Y? when a=1200, b=0.56 and x = 2500
a = 1200
b = 0.56
x = 2500
y = (a + b*x)
input("y: ")
print()
# Use input
#--------------- Write your code below----------------------------#
# Out:
# y: 2600

# %%
# Student Calculator
# Get user input to calculate total score

first_test = input("What is your score for first test: ")
second_test = input("What is your score for second test: ")
attendance = input("What is your score for attendance: ")
exam = input("What is your score for exam: ")
total_score = (first_test + second_test + attendance + exam)
input("total_score: ")
print()

#--------------- Write your code below----------------------------#
# Out:
# What is your score for first test: 35
# What is your score for second test: 65
# What is your score for attendance: 100
# What is your score for exam: 109
# total_score: 309

# %% [markdown]
# ## Strings

# %%
# Assign The quick brown fox jumps over the lazy dog to a Variable(text)
text = ("The quick brown fox jumps over the lazy dog")

# Slice the string to obtain quick brown fox
print(text[4:19])
# Slice the string to obtain the lazy dog
print(text[31:43])
# Use negative Indexing to obtain lazy dog
print(text[-9:])
# Obtain the Length of the string
print(len(text))
#--------------- Write your code below----------------------------#
# Out:
# quick brown fox
# the lazy dog
#  lazy dog
# 43

# %%
# Assign The quick brown fox jumps over the lazy dog to a Variable(text)
text = ("The quick brown fox jumps over the lazy dog")
strings_list = ['The', 'quick' , 'brown' , 'fox' , 'jumps' , 'over', 'the' , 'lazy' , 'dog',]
# Convert this string above into a list using one of the list methods
print(strings_list)
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
# Get input from user and Concatenate the code below

Name = input("What is your name?: ")
Age = input("How old are you?: ")
State = input("What is your state of origin?: ")
Profession = input("What is your profession?: ")
Bio = print(f"My name is {Name}, and i'm {Age} years old. I am from {State}, and i am a {Profession} by  profession.")

#--------------- Write your code below----------------------------#
# Out:
# What is your name?: George
# How old are you?: 35
# What is your state of origin?: Imo state
# What is your profession?: Data Engineer
# My name is George, and i'm 35 years old. I am from Imo state, and i am a Data Engineer  by  profession.

# %% [markdown]
# ## List

# %%
# Create a list of states in Nigeria

# Abia
# Adamawa
# Akwa Ibom
# Anambra
# Bayelsa
# Benue
# Borno
# Cross River
# Nasarawa
# Niger
# Ogun
# Ondo
# Osun
# Oyo
# Plateau
# Rivers
# Sokoto
# Taraba
# Yobe
# Zamfara

state = ['Abia','Adamawa', 'Akwa Ibom', 'Anambra', 'Bayelsa', 'Benue', 'Borno', 'Cross River', 'Nasarawa', 'Niger', 'Ogun', 'Ondo', 'Osun', 'Oyo','Plateau', 'Rivers', 'Sokoto', 'Taraba', 'Yobe', 'Zamfara'  ]

#--------------- Write your code below----------------------------#

# %%
# Q1: What is the total length of your list
state = ['Abia','Adamawa', 'Akwa Ibom', 'Anambra', 'Bayelsa', 'Benue', 'Borno', 'Cross River', 'Nasarawa', 'Niger', 'Ogun', 'Ondo', 'Osun', 'Oyo','Plateau', 'Rivers', 'Sokoto', 'Taraba', 'Yobe', 'Zamfara'  ]
print(len(state))
#--------------- Write your code below----------------------------#
# Out:
# 20

# %%
# Q2: Index and retrieve the first 10
state = ['Abia','Adamawa', 'Akwa Ibom', 'Anambra', 'Bayelsa', 'Benue', 'Borno', 'Cross River', 'Nasarawa', 'Niger', 'Ogun', 'Ondo', 'Osun', 'Oyo','Plateau', 'Rivers', 'Sokoto', 'Taraba', 'Yobe', 'Zamfara'  ]
print(state[:10])
#--------------- Write your code below----------------------------#
# Out:
# ['Abia', 'Adamawa', 'Akwa Ibom', 'Anambra', 'Bayelsa', 'Benue', 'Borno', 'Cross River', 'Nasarawa', 'Niger']

# %%
# Q3: Index and retrieve Cross River, Nasarawa, Niger, Ogun, Ondo, Osun, Oyo, Plateau
state = ['Abia','Adamawa', 'Akwa Ibom', 'Anambra', 'Bayelsa', 'Benue', 'Borno', 'Cross River', 'Nasarawa', 'Niger', 'Ogun', 'Ondo', 'Osun', 'Oyo','Plateau', 'Rivers', 'Sokoto', 'Taraba', 'Yobe', 'Zamfara']
print(state[7:15])
#--------------- Write your code below----------------------------#
# Out:
# ['Cross River', 'Nasarawa', 'Niger', 'Ogun', 'Ondo', 'Osun', 'Oyo', 'Plateau']

# %%
# Q4: Use Negative indexing to retrieve the last 5 states
state = ['Abia','Adamawa', 'Akwa Ibom', 'Anambra', 'Bayelsa', 'Benue', 'Borno', 'Cross River', 'Nasarawa', 'Niger', 'Ogun', 'Ondo', 'Osun', 'Oyo','Plateau', 'Rivers', 'Sokoto', 'Taraba', 'Yobe', 'Zamfara']
print(state[-5:])
#--------------- Write your code below----------------------------#
# Out:
# ['Rivers', 'Sokoto', 'Taraba', 'Yobe', 'Zamfara']

# %% [markdown]
# ## Dictionary

# %%
# Q1: Create a dictionary of states and governor in Nigeria

# Abia State: nil
# Bauchi State: Bala Muhammed
# Bayelsa State: Douye Diri
# Borno State: Babagana Zulum
# Ekiti State: nil
# Lagos State: Babajide Sanwo-Olu
# Anambra State: Charles Soludo
# Taraba State: Agbu Kefas


#--------------- Write your code below----------------------------#

# %%
# Q2: update Abia and Ekiti (Alex Otti, Biodun Oyebanji)

#--------------- Write your code below----------------------------#

# %%
# Q3: Add
# Cross River State: Bassey Otu
# Ebonyi State: Francis Nwifuru
# Sokoto State: Ahmad Aliyu

#--------------- Write your code below----------------------------#

# %%
# Q4: Remove Lagos, Sokoto, taraba and Kogi from the dictionary

#--------------- Write your code below----------------------------#

# %% [markdown]
# # General

# %%
# Q3: What datatype ensures its elements are immutable?

#--------------- Write your answer below----------------------------#

# %%
# Q4: What datatype of Python houses unordered elements?

#--------------- Write your answer below----------------------------#
